# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeepnama143/FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-06 18:14:47--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  98.7MB/s    in 0.7s
#
# 2024-05-06 18:14:49 (98.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6845   1706.07450v1  Many inverse problems are formulated as optimi...  stat
# 15214  1612.04538v1  We make one of the first attempts to build wor...    cs
# 10631   1202.0786v2  We study sparse principal components analysis ...  stat
# 13125  1611.01129v1  The completion of tensors, or high-order array...  stat
# 6351   1611.06080v1  While much research effort has been dedicated ...  stat
# ...             ...                                                ...   ...
# 31441  1803.04048v1  In classifier (or regression) fusion the aim i...    cs
# 4580    1111.0712v1  We propose a new online learning model for lea...    cs
# 6051   1606.05685v2  It is commonly believed that increasing the in...  stat
# 22754  1705.10813v3  Gaussian processes (GPs), or distributions ove...  stat
# 9850    1406.3496v1  Syndromic surveillance systems continuously mo...    cs
#
#                                                    title  year  \
# 6845   A Note on Learning Algorithms for Quadratic As...  2017
# 15214  Grammatical Constraints on Intra-sentential Co...  2016
# 10631  Minimax Rates of Estimation for Sparse PCA in ...  2012
# 13125        Cross: Efficient Low-rank Tensor Completion  2016
# 6351   A Generalized Stochastic Variational Bayesian ...  2016
# ...                                                  ...   ...
# 31441  Multiple Instance Choquet Integral Classifier ...  2018
# 4580            Online Learning with Preference Feedback  2011
# 6051   Using Visual Analytics to Interpret Predictive...  2016
# 22754  Large Linear Multi-output Gaussian Process Lea...  2017
# 9850   EigenEvent: An Algorithm for Event Detection f...  2014
#
#                                                 keywords
# 6845   [formulated, optimization, appropriate, distri...
# 15214  [sentential, switching, equivalence, constrain...
# 10631  [principal, components, dimensional, asymptoti...
# 13125  [completion, significant, attention, literatur...
# 6351   [dedicated, variables, attention, approximatio...
# ...                                                  ...
# 31441  [classifier, algorithms, performance, supervis...
# 4580   [preference, especially, applications, recomme...
# 6051   [increasing, interpretability, predictive, ins...
# 22754  [processes, distributions, arbitrary, function...
# 9850   [syndromic, surveillance, continuously, diagno...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6845     [formulated, optimization, appropriate, distri...
# 15214    [sentential, switching, equivalence, constrain...
# 10631    [principal, components, dimensional, asymptoti...
# 13125    [completion, significant, attention, literatur...
# 6351     [dedicated, variables, attention, approximatio...
#                                ...
# 22384    [estimating, multivariate, stationary, precisi...
# 26065    [classification, automatically, fundamental, u...
# 1111     [supervised, feedforward, supervisory, associa...
# 21731    [unsupervised, exploratory, inference, restric...
# 19200    [addresses, resolving, uncertainty, developed,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4509 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e39c9c84-10ff-45e9-9f9e-f2ac79228c96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e39c9c84-10ff-45e9-9f9e-f2ac79228c96")) {                    Plotly.newPlot(                        "e39c9c84-10ff-45e9-9f9e-f2ac79228c96",                        [{"x":["collection","appropriate","tradeoffs","algorithms","predictive","optimization","distribution","previously","performance","assignment","fundamental","understanding","observing","interested","supervise","relaxation","intriguingly","complexity","techniques","resulting","formulated","instances","illustrate","distributions","quadratic","algorithm","computational","constraint","empirical","equivalence","sentential","theoretical","constraints","grammatical","switching","components","eigenvector","constrained","particular","principal","asymptotic","estimation","dimensional","convergence","dimensions","analyzing","measurements","illustrated","implement","noiseless","procedure","guaranteed","completion","literature","primarily","attention","measurement","simulation","implementation","neuroimaging","recovered","efficient","significant","uniformly","framework","dedicated","addresses","optimized","iteration","overfitting","structural","outperforms","representation","competitive","variational","regression","structure","hyperparameter","interaction","estimator","variables","interestingly","stochastic","decomposable","parameterization","generalized","preserving","evaluation","improvements","implementations","approximations","exploiting","posteriori","intractable","exploited","shortcomings","frequencies","treatment","portability","mechanisms","interpreter","designing","standardization","implementing","discusses","representations","organization","implemented","distinguishes","integrated","requirements","tradition","standalone","extensible","independent","initiative","intermediate","alternatives","estimators","preference","following","aggregation","perception","likelihood","alternative","potential","corresponds","scenarios","crowdsourcing","formulate","intuitions","harnessed","practical","considerably","demonstrating","practices","complement","aggregated","traditional","individual","challenges","supervised","comparisons","relations","difficult","important","collecting","lightweight","effective","continuous","robustness","decomposed","dependence","motivated","currently","classification","reconstructs","investigate","theoretically","available","empirically","favorably","benchmarks","characterize","experiments","conclusions","induction","faithfulness","different","extensive","graphically","subroutines","experimental","condition","application","irreducible","neighborhood","information","topographic","neuroscientists","demonstrate","distributed","resonance","algorithmic","synthetic","underlying","resolution","respectively","functional","processing","dimensionality","increasing","analytical","hierarchical","australian","introduce","dependency","completely","preparation","automatic"],"y":[82,87,5,621,58,331,198,112,904,37,69,158,16,25,4,14,2,247,375,154,36,78,70,109,34,845,297,100,156,22,3,168,130,18,7,99,7,64,280,26,22,228,158,131,35,60,57,23,79,1,113,30,26,117,21,168,37,63,126,4,10,412,242,18,557,23,55,59,51,26,79,259,354,143,61,139,325,7,78,30,123,19,140,9,5,75,47,216,113,32,27,80,10,26,34,14,14,31,2,57,5,39,7,19,26,245,13,120,8,53,39,4,5,5,122,4,33,23,20,29,85,31,35,58,93,158,21,98,9,53,2,2,151,27,37,7,14,10,176,120,113,183,26,79,151,337,11,11,273,104,95,14,26,65,50,527,4,128,37,262,69,17,89,46,591,22,19,1,767,149,0,1,396,35,250,1,23,692,2,0,554,108,13,43,132,119,111,72,34,273,50,120,23,99,1,312,42,31,7,180],"type":"bar"},{"x":["collection","appropriate","tradeoffs","algorithms","predicti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4509,), (4509, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Natural</span> <span style=''>Color</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.8620689655172413);'>Enhancement</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Modified</span> <span style='background-color:rgba(255, 0, 0, 0.35999999999999993);'>Multiscale</span> <span style=''>Retinex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style='background-color:rgba(0, 255, 0, 0.30513595166163143);'>Evaluation</span> <span style=''>usingWavelet</span> <span style=''>Energy</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>new</span> <span style=''>color</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8620689655172413);'>enhancement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>based</span> <span style=''>on</span> <span style=''>modified</span> <span style='background-color:rgba(255, 0, 0, 0.35999999999999993);'>MultiScale</span> <span style=''>Retinex(MSR)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>visual</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>enhanced</span> <span style=''>images</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>evaluated</span> <span style=''>using</span> <span style=''>a</span> <span style=''>new</span> <span style=''>metric</span> <span style=''>namely</span> <span style=''>wavelet</span> <span style=''>energy</span> <span style=''>The</span> <span style=''>color</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8620689655172413);'>enhancement</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>down</span> <span style=''>sampling</span> <span style=''>the</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>of</span> <span style=''>HSV</span> <span style=''>color</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>converted</span> <span style=''>image</span> <span style=''>into</span> <span style=''>three</span> <span style=''>scales</span> <span style=''>(normal</span> <span style=''>medium</span> <span style=''>and</span> <span style=''>fine)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>the</span> <span style=''>contrast</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>stretching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operation</span> <span style=''>These</span> <span style=''>down</span> <span style=''>sampled</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>are</span> <span style=''>enhanced</span> <span style=''>using</span> <span style=''>the</span> <span style=''>MSR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.44);'>reconstructed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>each</span> <span style=''>pixels</span> <span style=''>of</span> <span style=''>the</span> <span style=''>lower</span> <span style=''>scale</span> <span style=''>image</span> <span style=''>with</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>upper</span> <span style=''>sc ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Vectorial</span> <span style=''>Data</span> <span style=''>and</span> <span style=''>Network</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrative</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>objects</span> <span style=''>given</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>vectorial</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>each</span> <span style=''>object</span> <span style=''>and</span> <span style=''>network</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>objects</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>general</span> <span style=''>model</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>cluster</span> <span style=''>the</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>within</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>only</span> <span style=''>handle</span> <span style=''>one</span> <span style=''>data</span> <span style=''>type</span> <span style=''>or</span> <span style=''>depend</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforming</span> <span style=''>one</span> <span style=''>data</span> <span style=''>type</span> <span style=''>to</span> <span style=''>another</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>A</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>general</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>is</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Glottochronologic</span> <span style=''>Retrognostic</span> <span style=''>of</span> <span style=''>Language</span> <span style=''>System</span> <br/><br/><span style=''>A</span> <span style=''>glottochronologic</span> <span style=''>retrognostic</span> <span style=''>of</span> <span style=''>language</span> <span style=''>system</span> <span style=''>is</span> <span style=''>proposed</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>in</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Analytical</span> <span style=''>Learning</span> <span style=''>Theory</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>measure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>learning</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviors</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>interest</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>learning</span> <span style=''>theory</span> <span style=''>has</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>abilities</span> <span style=''>1)</span> <span style=''>to</span> <span style=''>utilize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualities</span> <span style=''>of</span> <span style=''>each</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>on</span> <span style=''>the</span> <span style=''>path</span> <span style=''>from</span> <span style=''>raw</span> <span style=''>inputs</span> <span style=''>to</span> <span style=''>outputs</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learning</span> <span style=''>2)</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>errors</span> <span style=''>possibly</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrarily</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>spaces</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrarily</span> <span style=''>large</span> <span style=''>capacity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style=''>complexity)</span> <span style=''>and</span> <span style=''>non</span> <span style=''>stablenon</span> <span style=''>robust</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>3)</span> <span style=''>to</span> <span style=''>clearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>problem</span> <span style=''>instance</span> <span style=''>from</span> <span style=''>each</span> <span style=''>other</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>bounds</span> <span style=''>are</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>hold</span> <span style=''>true</span> <span style=''>even</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(255, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1261132882080513)
# 	architecture (0.08122550765942287)
# 	segmentation (0.06768792304951905)
# 	experimental (0.14107588172426078)
# 	challenging (0.10509440684004275)
# 	information (0.24652654079087993)
# 	detection (0.12255076594228714)
# 	recognition (0.1261132882080513)
# 	different (0.27324545778411113)
# 	convolutional (0.1396508728179551)
#
# Some Statistics words are:
# 	algorithm (0.3833416959357752)
# 	stochastic (0.13346713497240342)
# 	theoretical (0.14751630707476165)
# 	estimation (0.17009533366783744)
# 	variables (0.14550928248871048)
# 	statistical (0.16457601605619668)
# 	inference (0.19668840943301555)
# 	distribution (0.19869543401906672)
# 	dimensional (0.18615153035624687)
# 	regression (0.18615153035624687)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35493e89-2668-46d6-86d7-07c2f8fd06ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35493e89-2668-46d6-86d7-07c2f8fd06ba")) {                    Plotly.newPlot(                        "35493e89-2668-46d6-86d7-07c2f8fd06ba",                        [{"x":["collection","appropriate","tradeoffs","algorithms","predictive","optimization","distribution","previously","performance","assignment","fundamental","understanding","observing","interested","supervise","relaxation","intriguingly","complexity","techniques","resulting","formulated","instances","illustrate","distributions","quadratic","algorithm","computational","constraint","empirical","equivalence","sentential","theoretical","constraints","grammatical","switching","components","eigenvector","constrained","particular","principal","asymptotic","estimation","dimensional","convergence","dimensions","analyzing","measurements","illustrated","implement","noiseless","procedure","guaranteed","completion","literature","primarily","attention","measurement","simulation","implementation","neuroimaging","recovered","efficient","significant","uniformly","framework","dedicated","addresses","optimized","iteration","overfitting","structural","outperforms","representation","competitive","variational","regression","structure","hyperparameter","interaction","estimator","variables","interestingly","stochastic","decomposable","parameterization","generalized","preserving","evaluation","improvements","implementations","approximations","exploiting","posteriori","intractable","exploited","shortcomings","frequencies","treatment","portability","mechanisms","interpreter","designing","standardization","implementing","discusses","representations","organization","implemented","distinguishes","integrated","requirements","tradition","standalone","extensible","independent","initiative","intermediate","alternatives","estimators","preference","following","aggregation","perception","likelihood","alternative","potential","corresponds","scenarios","crowdsourcing","formulate","intuitions","harnessed","practical","considerably","demonstrating","practices","complement","aggregated","traditional","individual","challenges","supervised","comparisons","relations","difficult","important","collecting","lightweight","effective","continuous","robustness","decomposed","dependence","motivated","currently","classification","reconstructs","investigate","theoretically","available","empirically","favorably","benchmarks","characterize","experiments","conclusions","induction","faithfulness","different","extensive","graphically","subroutines","experimental","condition","application","irreducible","neighborhood","information","topographic","neuroscientists","demonstrate","distributed","resonance","algorithmic","synthetic","underlying","resolution","respectively","functional","processing","dimensionality","increasing","analytical","hierarchical","australian","introduce","dependency","completely","preparation","automatic","centroids","contextual","resources","mechanism","stability","extracting","classifier","determine","correction","unsupervised","processes","comprises","classifiers","sentiment","benchmark","generalization","describes","clustering","promising","detection","discovery","eigenvectors","therefore","originally","utilizing","distorted","informative","particularly","intensity","distortions","segmentation","generation","including","constructed","partition","appropriately","inference","propositions","observations","gaussians","normalized","organized","demonstration","derivation","posterior","subsequently","increments","exchangeable","probability","dependent","combinations","necessary","combination","distillation","predictio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	graphically
# 	neuroscientists
# 	exchangeable
# 	interpolating
# 	homoscedastic
# 	multicore
# 	textitfixed
# 	frequentist
# 	transelliptical
# 	elucidating
# 	therapies
# 	recombines
# 	parallelisation
# 	martingale
# 	liblinear
# 	statisticians
# 	tolerates
# 	transcriptional
# 	chervonenkis
# 	archetypes
# Some words which never appear in Statistics papers:
# 	sentential
# 	grammatical
# 	portability
# 	interpreter
# 	fixations
# 	photometric
# 	reflections
# 	reflectance
# 	inferencing
# 	conversing
# 	utterances
# 	compliant
# 	cerebellar
# 	valuation
# 	volunteer
# 	javascript
# 	electronics
# 	inheritance
# 	defeasible
# 	nonmonotonic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069461923324841e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7466666666666667
